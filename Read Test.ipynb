# %%
import qlab
st = qlab.connect_scpi()
snap = qlab.read_trace(st)
# Out:
# [qlab] direct-SCPI station: 'CH1_S11_1' on the N5222B at USB0::0x2A8D::0x2A01::MY58421887::0::INSTR.  Data -> C:/Data_HH/stub-s3
# trace         : 'CH1_S11_1'   (2001 points)
# freq range    : 6.000000 -> 7.000000 GHz
# |S| via SDATA : min 4.47  max 10.32  p2p 5.84 dB
# screen FDATA  : min 4.47  max 10.32  p2p 5.84 dB
#               -> matches our SDATA decode: the data path is confirmed end to end.
# min |S| at    : 6.432000 GHz
# saved         : C:/Data_HH/stub-s3\20260721\115054_vna_snapshot\vna_snapshot.csv
